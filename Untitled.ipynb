# %%
import pandas as pd
import os
from matplotlib import pyplot as plt
arya = []
for filename in os.listdir("Resources/names"):
    if 'yob' in filename:
        name = pd.read_csv(f"Resources/names/{filename}",header=None)
        name["year"] = os.path.splitext(filename)[0][-4:]
        
        arya.append((name[(name[0]=="Arya") & (name[1] == "F")]))
for x in range(len(arya)):
    plt.scatter(arya[x]['year'],arya[x][2], c='b')
    plt.xticks(rotation=90)
plt.show()

# %%
name[(name[0]=="Arya") & (name[1] == "F")]
# Out:
#         0  1     2  year
# 134  Arya  F  2156  2017

# %%
name[name[1]=="F"]
# Out:
#                0  1      2  year
# 0           Emma  F  19738  2017
# 1         Olivia  F  18632  2017
# 2            Ava  F  15902  2017
# 3       Isabella  F  15100  2017
# 4         Sophia  F  14831  2017
# 5            Mia  F  13437  2017
# 6      Charlotte  F  12893  2017
# 7         Amelia  F  11800  2017
# 8         Evelyn  F  10675  2017
# 9        Abigail  F  10551  2017
# 10        Harper  F  10451  2017
# 11         Emily  F   9746  2017
# 12     Elizabeth  F   8915  2017
# 13         Avery  F   8186  2017
# 14         Sofia  F   8134  2017
# 15          Ella  F   8014  2017
# 16       Madison  F   7847  2017
# 17      Scarlett  F   7679  2017
# 18      Victoria  F   7267  2017
# 19          Aria  F   7132  2017
# 20         Grace  F   6991  2017
# 21         Chloe  F   6912  2017
# 22        Camila  F   6752  2017
# 23      Penelope  F   6639  2017
# 24         Riley  F   6343  2017
# 25         Layla  F   6274  2017
# 26       Lillian  F   6132  2017
# ...

# %%
arya.append((name[name[0]=="Arya"] & name[name[1]=="F"]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1788         try:
# -> 1789             result = op(x, y)
#    1790         except TypeError:
#
# TypeError: unsupported operand type(s) for &: 'float' and 'bool'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-00bebb5d8508> in <module>
# ----> 1 arya.append((name[name[0]=="Arya"] & name[name[1]=="F"]))
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in f(self, other, axis, level, fill_value)
#    2021             # Another DataFrame
#    2022             pass_op = op if should_series_dispatch(self, other, op) else na_op
# -> 2023             return self._combine_frame(other, pass_op, fill_value, level)
# ...

# %%
arya = []
for filename in os.listdir("Resources/names"):
    if 'yob' in filename:
        name = pd.read_csv(f"Resources/names/{filename}",header=None)
        name["year"] = os.path.splitext(filename)[0][-4:]
        
        arya.append(name.loc[name[0]=="Joseph"])
for x in range(len(arya)):
    plt.scatter(arya[x]['year'],arya[x][2], c='b')
    plt.xticks(rotation=90)
plt.show()
